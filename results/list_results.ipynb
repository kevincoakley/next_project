# %% [markdown]
# # List Results
#
# This notebook creates a table of examples with the hardware and software environments.

# %%
import csv, os
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

path = "./"

list_of_files = []

results_df = pd.DataFrame(
    {
        "example": pd.Series(dtype="str"),
        "hardware_environment": pd.Series(dtype="str"),
        "software_environment": pd.Series(dtype="str"),
        "fixed-seed": pd.Series(dtype="bool"),
        "random": pd.Series(dtype="bool"),
        "2628917891": pd.Series(dtype="float"),
    }
)

#
# Find all of the csv files in the results directory
#
for root, dirs, files in os.walk(path):
    for file in files:
        # Allow results to be ignored by including "ignore" in the directory or file name
        if "ignore" not in root:
            if file.endswith(".csv"):
                list_of_files.append(os.path.join(root, file).replace(path, ""))

#
# Create a dataframe with the results
#
for file in list_of_files:
    file_split = file.split("/")

    # Get the example name from the file path
    example = file_split[0]

    # Decide if it is fixed-seed or random from the file path
    if "fixed-seed" in file_split[2]:
        fixed_seed = True
    else:
        fixed_seed = False
    if "random" in file_split[2]:
        random = True
    else:
        random = False

    #
    # Read the csv file and verify it has 101 lines and store the seed
    # from the second line
    #
    with open(file, "r") as csv_file:

        # Verify the csv file has 101 lines
        lines = len(csv_file.readlines())
        if lines != 101:
            print("ERROR: %s has %d lines" % (file, lines))

        # if the seed is fixed, read the seed from the csv file
        if fixed_seed:
            # Read the file again
            csv_file.seek(0)

            # Read the seed from the second line
            rows = csv_file.readlines()
            seed = float(rows[1].split(",")[-1])
        else:
            seed = pd.NA

    # Get the hardware and software environment from the file path
    hardware_environment = "%s/%s" % (file_split[3], file_split[4])
    software_environment = file_split[5]

    #
    # Check the dataframe to see if the example, hardware environment, and software environment
    # have already been added. If they have, update the fixed-seed and random columns.
    #
    if (
        (results_df["example"] == example)
        & (results_df["hardware_environment"] == hardware_environment)
        & (results_df["software_environment"] == software_environment)
    ).any():
        if fixed_seed:
            results_df.loc[
                (results_df.example == example)
                & (results_df.hardware_environment == hardware_environment)
                & (results_df.software_environment == software_environment),
                "fixed-seed",
            ] = True
        if random:
            results_df.loc[
                (results_df.example == example)
                & (results_df.hardware_environment == hardware_environment)
                & (results_df.software_environment == software_environment),
                "random",
            ] = True
    else:
        #
        # If the example, hardware environment, and software environment do not exisit in
        # the dataframe then add a new row
        #
        results_df.loc[len(results_df.index)] = [
            example,
            hardware_environment,
            software_environment,
            fixed_seed,
            random,
            seed,
        ]

display(
    results_df.sort_values(
        by=["example", "hardware_environment", "software_environment"]
    )
)
# Out:
#                                example hardware_environment  \
# 15             bidirectional_lstm_imdb             OSG/A100
# 50             bidirectional_lstm_imdb             OSG/A100
# 20             bidirectional_lstm_imdb             OSG/A100
# 18             bidirectional_lstm_imdb             OSG/A100
# 19             bidirectional_lstm_imdb             OSG/A100
# 17             bidirectional_lstm_imdb             OSG/A100
# 51             bidirectional_lstm_imdb             OSG/A100
# 16             bidirectional_lstm_imdb             OSG/A100
# 32             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 38             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 36             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 37             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 34             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 35             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 33             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 9              bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 14             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 12             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 13             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 10             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 11             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 21             bidirectional_lstm_imdb         OSG/RTXA5000
# 25             bidirectional_lstm_imdb         OSG/RTXA5000
# 23             bidirectional_lstm_imdb         OSG/RTXA5000
# 24             bidirectional_lstm_imdb         OSG/RTXA5000
# 22             bidirectional_lstm_imdb         OSG/RTXA5000
# 26             bidirectional_lstm_imdb             OSG/V100
# 31             bidirectional_lstm_imdb             OSG/V100
# 29             bidirectional_lstm_imdb             OSG/V100
# 30             bidirectional_lstm_imdb             OSG/V100
# 27             bidirectional_lstm_imdb             OSG/V100
# 28             bidirectional_lstm_imdb             OSG/V100
# 46             bidirectional_lstm_imdb            OSG/i5117
# 49             bidirectional_lstm_imdb            OSG/i5117
# 47             bidirectional_lstm_imdb            OSG/i5117
# 48             bidirectional_lstm_imdb            OSG/i5117
# 39             bidirectional_lstm_imdb          OSG/iE52650
# 45             bidirectional_lstm_imdb          OSG/iE52650
# 43             bidirectional_lstm_imdb          OSG/iE52650
# 44             bidirectional_lstm_imdb          OSG/iE52650
# 41             bidirectional_lstm_imdb          OSG/iE52650
# 42             bidirectional_lstm_imdb          OSG/iE52650
# 40             bidirectional_lstm_imdb          OSG/iE52650
# 0              bidirectional_lstm_imdb             SDSC/A40
# 2              bidirectional_lstm_imdb             SDSC/A40
# 8              bidirectional_lstm_imdb             SDSC/A40
# 6              bidirectional_lstm_imdb             SDSC/A40
# 7              bidirectional_lstm_imdb             SDSC/A40
# 3              bidirectional_lstm_imdb             SDSC/A40
# 4              bidirectional_lstm_imdb             SDSC/A40
# 1              bidirectional_lstm_imdb             SDSC/A40
# 5              bidirectional_lstm_imdb             SDSC/A40
# 134  image_classification_from_scratch             OSG/A100
# 133  image_classification_from_scratch             OSG/A100
# 132  image_classification_from_scratch             SDSC/A40
# 131  image_classification_from_scratch             SDSC/A40
# 129  image_classification_from_scratch             SDSC/A40
# 128  image_classification_from_scratch             SDSC/A40
# 130  image_classification_from_scratch             SDSC/A40
# 71           imbalanced_classification             OSG/A100
# 74           imbalanced_classification             OSG/A100
# 73           imbalanced_classification             OSG/A100
# 72           imbalanced_classification             OSG/A100
# 69           imbalanced_classification             OSG/A100
# 70           imbalanced_classification             OSG/A100
# 68           imbalanced_classification             OSG/A100
# 64           imbalanced_classification    OSG/AMD_EPYC_7662
# 67           imbalanced_classification    OSG/AMD_EPYC_7662
# 66           imbalanced_classification    OSG/AMD_EPYC_7662
# 65           imbalanced_classification    OSG/AMD_EPYC_7662
# 62           imbalanced_classification    OSG/AMD_EPYC_7662
# 63           imbalanced_classification    OSG/AMD_EPYC_7662
# 61           imbalanced_classification    OSG/AMD_EPYC_7662
# 78           imbalanced_classification          OSG/iE52650
# 81           imbalanced_classification          OSG/iE52650
# 80           imbalanced_classification          OSG/iE52650
# 79           imbalanced_classification          OSG/iE52650
# 76           imbalanced_classification          OSG/iE52650
# 77           imbalanced_classification          OSG/iE52650
# 75           imbalanced_classification          OSG/iE52650
# 60           imbalanced_classification             SDSC/A40
# 56           imbalanced_classification             SDSC/A40
# 59           imbalanced_classification             SDSC/A40
# 58           imbalanced_classification             SDSC/A40
# 57           imbalanced_classification             SDSC/A40
# 53           imbalanced_classification             SDSC/A40
# 54           imbalanced_classification             SDSC/A40
# 52           imbalanced_classification             SDSC/A40
# 55           imbalanced_classification             SDSC/A40
# 104   text_classification_from_scratch             OSG/A100
# 127   text_classification_from_scratch             OSG/A100
# 105   text_classification_from_scratch             OSG/A100
# 108   text_classification_from_scratch             OSG/A100
# 107   text_classification_from_scratch             OSG/A100
# 106   text_classification_from_scratch             OSG/A100
# 101   text_classification_from_scratch             OSG/A100
# 102   text_classification_from_scratch             OSG/A100
# 100   text_classification_from_scratch             OSG/A100
# 103   text_classification_from_scratch             OSG/A100
# 117   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 113   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 116   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 115   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 114   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 110   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 111   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 109   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 112   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 99    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 95    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 98    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 97    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 96    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 92    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 93    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 91    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 94    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 126   text_classification_from_scratch          OSG/iE52650
# 122   text_classification_from_scratch          OSG/iE52650
# 125   text_classification_from_scratch          OSG/iE52650
# 124   text_classification_from_scratch          OSG/iE52650
# 123   text_classification_from_scratch          OSG/iE52650
# 119   text_classification_from_scratch          OSG/iE52650
# 120   text_classification_from_scratch          OSG/iE52650
# 118   text_classification_from_scratch          OSG/iE52650
# 121   text_classification_from_scratch          OSG/iE52650
# 90    text_classification_from_scratch             SDSC/A40
# 87    text_classification_from_scratch             SDSC/A40
# 89    text_classification_from_scratch             SDSC/A40
# 88    text_classification_from_scratch             SDSC/A40
# 83    text_classification_from_scratch             SDSC/A40
# 86    text_classification_from_scratch             SDSC/A40
# 85    text_classification_from_scratch             SDSC/A40
# 84    text_classification_from_scratch             SDSC/A40
# 82    text_classification_from_scratch             SDSC/A40
#
#                         software_environment  fixed-seed  random 2628917891
# 15   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True    True    0.83916
# 50   tensorflow_2.11.0-gpu-cuda11.8-cudnn8.6       False    True       <NA>
# 20    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True     0.8176
# 18    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True     0.8176
# 19                  tensorflow_22.06-tf2-py3        True    True    0.85404
# 17                  tensorflow_22.09-tf2-py3        True    True     0.8452
# 51                  tensorflow_22.10-tf2-py3       False    True       <NA>
# 16                  tensorflow_22.11-tf2-py3        True    True    0.85428
# 32   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True    True    0.85844
# 38    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True    0.85988
# 36    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True    0.86032
# 37                  tensorflow_22.06-tf2-py3        True    True     0.8672
# 34                  tensorflow_22.09-tf2-py3        True    True     0.8672
# 35                  tensorflow_22.10-tf2-py3        True    True    0.85904
# 33                  tensorflow_22.11-tf2-py3        True    True    0.85904
# 9    tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True   False    0.84472
# 14    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False     0.8296
# 12    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False     0.8296
# 13                  tensorflow_22.06-tf2-py3        True   False    0.86564
# 10                  tensorflow_22.09-tf2-py3        True   False    0.86176
# 11                  tensorflow_22.10-tf2-py3        True   False    0.83684
# 21   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True   False    0.85404
# 25    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False    0.85584
# 23    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False    0.85584
# 24                  tensorflow_22.06-tf2-py3        True   False     0.8546
# 22                  tensorflow_22.10-tf2-py3        True   False    0.86548
# 26   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True   False    0.85684
# 31    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False    0.86552
# 29    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False    0.86552
# 30                  tensorflow_22.06-tf2-py3        True   False      0.866
# 27                  tensorflow_22.09-tf2-py3        True   False    0.83448
# 28                  tensorflow_22.10-tf2-py3        True   False      0.869
# 46   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True   False    0.86244
# 49    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False    0.82472
# 47    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False      0.864
# 48                  tensorflow_22.06-tf2-py3        True   False    0.85764
# 39   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True    True    0.84072
# 45    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True    0.85324
# 43    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True    0.86288
# 44                  tensorflow_22.06-tf2-py3        True    True     0.8672
# 41                  tensorflow_22.09-tf2-py3        True    True     0.8672
# 42                  tensorflow_22.10-tf2-py3        True    True    0.85904
# 40                  tensorflow_22.11-tf2-py3        True    True    0.85904
# 0    tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True    True    0.85404
# 2    tensorflow_2.11.0-gpu-cuda11.8-cudnn8.6        True    True    0.85604
# 8     tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True    0.85584
# 6     tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True    0.85584
# 7                   tensorflow_22.06-tf2-py3        True    True    0.86156
# 3                   tensorflow_22.09-tf2-py3        True    True     0.8332
# 4                   tensorflow_22.10-tf2-py3        True    True    0.85752
# 1                   tensorflow_22.11-tf2-py3        True    True    0.85752
# 5                   tensorflow_22.12-tf2-py3        True    True    0.85752
# 134                    tensorflow_2.11.0-gpu        True   False   0.876762
# 133                 tensorflow_22.11-tf2-py3        True   False   0.742631
# 132                    tensorflow_2.10.1-gpu        True    True   0.881461
# 131                    tensorflow_2.11.0-gpu        True    True   0.831482
# 129                 tensorflow_22.10-tf2-py3        True    True   0.790474
# 128                 tensorflow_22.11-tf2-py3        True    True   0.790474
# 130                 tensorflow_22.12-tf2-py3        True    True   0.790474
# 71                     tensorflow_2.11.0-gpu        True   False   0.989203
# 74                      tensorflow_2.8.0-gpu        True   False   0.991152
# 73                      tensorflow_2.9.1-gpu        True   False   0.991152
# 72                  tensorflow_22.06-tf2-py3        True   False    0.99519
# 69                  tensorflow_22.09-tf2-py3        True   False    0.99519
# 70                  tensorflow_22.10-tf2-py3        True   False   0.984972
# 68                  tensorflow_22.11-tf2-py3        True   False   0.984972
# 64                     tensorflow_2.11.0-gpu        True   False    0.98125
# 67                      tensorflow_2.8.0-gpu        True   False   0.991521
# 66                      tensorflow_2.9.1-gpu        True   False   0.991187
# 65                  tensorflow_22.06-tf2-py3        True   False   0.978792
# 62                  tensorflow_22.09-tf2-py3        True   False   0.978792
# 63                  tensorflow_22.10-tf2-py3        True   False   0.986886
# 61                  tensorflow_22.11-tf2-py3        True   False   0.986886
# 78                     tensorflow_2.11.0-gpu        True   False   0.987412
# 81                      tensorflow_2.8.0-gpu        True   False   0.994329
# 80                      tensorflow_2.9.1-gpu        True   False   0.987869
# 79                  tensorflow_22.06-tf2-py3        True   False   0.992047
# 76                  tensorflow_22.09-tf2-py3        True   False   0.992047
# 77                  tensorflow_22.10-tf2-py3        True   False   0.992311
# 75                  tensorflow_22.11-tf2-py3        True   False   0.992311
# 60                     tensorflow_2.10.1-gpu        True    True   0.995242
# 56                     tensorflow_2.11.0-gpu        True    True    0.99296
# 59                      tensorflow_2.8.0-gpu        True    True   0.996155
# 58                      tensorflow_2.9.1-gpu        True    True   0.996155
# 57                  tensorflow_22.06-tf2-py3        True    True   0.990836
# 53                  tensorflow_22.09-tf2-py3        True    True   0.990836
# 54                  tensorflow_22.10-tf2-py3        True    True   0.992943
# 52                  tensorflow_22.11-tf2-py3        True    True   0.992943
# 55                  tensorflow_22.12-tf2-py3        True    True   0.992943
# 104                        tensorflow_2.10.1        True   False      0.862
# 127                    tensorflow_2.10.1-gpu       False    True       <NA>
# 105                    tensorflow_2.11.0-gpu        True   False     0.8744
# 108                     tensorflow_2.8.0-gpu        True    True      0.872
# 107                     tensorflow_2.9.1-gpu        True    True      0.872
# 106                 tensorflow_22.06-tf2-py3        True    True     0.8606
# 101                 tensorflow_22.09-tf2-py3        True    True      0.865
# 102                 tensorflow_22.10-tf2-py3        True    True     0.8738
# 100                 tensorflow_22.11-tf2-py3        True    True     0.8738
# 103                 tensorflow_22.12-tf2-py3        True    True     0.8738
# 117                    tensorflow_2.10.1-gpu        True    True       0.87
# 113                    tensorflow_2.11.0-gpu        True   False     0.8746
# 116                     tensorflow_2.8.0-gpu        True    True      0.853
# 115                     tensorflow_2.9.1-gpu        True    True     0.8666
# 114                 tensorflow_22.06-tf2-py3        True    True     0.8622
# 110                 tensorflow_22.09-tf2-py3        True    True     0.8622
# 111                 tensorflow_22.10-tf2-py3        True    True     0.8684
# 109                 tensorflow_22.11-tf2-py3        True    True     0.8684
# 112                 tensorflow_22.12-tf2-py3        True    True     0.8684
# 99                     tensorflow_2.10.1-gpu        True    True       0.87
# 95                     tensorflow_2.11.0-gpu        True   False     0.8746
# 98                      tensorflow_2.8.0-gpu        True    True      0.853
# 97                      tensorflow_2.9.1-gpu        True    True     0.8666
# 96                  tensorflow_22.06-tf2-py3        True    True     0.8622
# 92                  tensorflow_22.09-tf2-py3        True    True     0.8622
# 93                  tensorflow_22.10-tf2-py3        True    True     0.8684
# 91                  tensorflow_22.11-tf2-py3        True    True     0.8684
# 94                  tensorflow_22.12-tf2-py3        True    True     0.8684
# 126                    tensorflow_2.10.1-gpu        True    True      0.868
# 122                    tensorflow_2.11.0-gpu        True   False     0.8748
# 125                     tensorflow_2.8.0-gpu        True    True     0.8632
# 124                     tensorflow_2.9.1-gpu        True    True      0.862
# 123                 tensorflow_22.06-tf2-py3        True    True     0.8664
# 119                 tensorflow_22.09-tf2-py3        True    True     0.8664
# 120                 tensorflow_22.10-tf2-py3        True    True     0.8708
# 118                 tensorflow_22.11-tf2-py3        True    True     0.8708
# 121                 tensorflow_22.12-tf2-py3        True    True     0.8708
# 90                     tensorflow_2.10.1-gpu        True    True     0.8716
# 87                     tensorflow_2.11.0-gpu        True    True     0.8636
# 89                      tensorflow_2.8.0-gpu        True    True     0.8672
# 88                      tensorflow_2.9.1-gpu        True    True     0.8672
# 83                      tensorflow_22.06-tf2        True    True     0.8692
# 86                      tensorflow_22.09-tf2        True    True     0.8602
# 85                      tensorflow_22.10-tf2        True    True     0.8614
# 84                      tensorflow_22.11-tf2        True    True     0.8614
# 82                      tensorflow_22.12-tf2        True    True     0.8614

# %% [markdown]
# Create a table of all of the results that contain duplicate results on the fixed seed runs.

# %%
seed_df = results_df["2628917891"]

display(
    results_df[seed_df.isin(seed_df[seed_df.duplicated()])].sort_values(
        by=["example", "2628917891", "hardware_environment", "software_environment"]
    )
)
# Out:
#                                example hardware_environment  \
# 20             bidirectional_lstm_imdb             OSG/A100
# 18             bidirectional_lstm_imdb             OSG/A100
# 14             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 12             bidirectional_lstm_imdb    OSG/QuadroRTX5000
# 19             bidirectional_lstm_imdb             OSG/A100
# 21             bidirectional_lstm_imdb         OSG/RTXA5000
# 0              bidirectional_lstm_imdb             SDSC/A40
# 25             bidirectional_lstm_imdb         OSG/RTXA5000
# 23             bidirectional_lstm_imdb         OSG/RTXA5000
# 8              bidirectional_lstm_imdb             SDSC/A40
# 6              bidirectional_lstm_imdb             SDSC/A40
# 4              bidirectional_lstm_imdb             SDSC/A40
# 1              bidirectional_lstm_imdb             SDSC/A40
# 5              bidirectional_lstm_imdb             SDSC/A40
# 35             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 33             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 42             bidirectional_lstm_imdb          OSG/iE52650
# 40             bidirectional_lstm_imdb          OSG/iE52650
# 31             bidirectional_lstm_imdb             OSG/V100
# 29             bidirectional_lstm_imdb             OSG/V100
# 37             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 34             bidirectional_lstm_imdb    OSG/AMD_EPYC_7452
# 44             bidirectional_lstm_imdb          OSG/iE52650
# 41             bidirectional_lstm_imdb          OSG/iE52650
# 50             bidirectional_lstm_imdb             OSG/A100
# 51             bidirectional_lstm_imdb             OSG/A100
# 129  image_classification_from_scratch             SDSC/A40
# 128  image_classification_from_scratch             SDSC/A40
# 130  image_classification_from_scratch             SDSC/A40
# 65           imbalanced_classification    OSG/AMD_EPYC_7662
# 62           imbalanced_classification    OSG/AMD_EPYC_7662
# 70           imbalanced_classification             OSG/A100
# 68           imbalanced_classification             OSG/A100
# 63           imbalanced_classification    OSG/AMD_EPYC_7662
# 61           imbalanced_classification    OSG/AMD_EPYC_7662
# 57           imbalanced_classification             SDSC/A40
# 53           imbalanced_classification             SDSC/A40
# 74           imbalanced_classification             OSG/A100
# 73           imbalanced_classification             OSG/A100
# 79           imbalanced_classification          OSG/iE52650
# 76           imbalanced_classification          OSG/iE52650
# 77           imbalanced_classification          OSG/iE52650
# 75           imbalanced_classification          OSG/iE52650
# 54           imbalanced_classification             SDSC/A40
# 52           imbalanced_classification             SDSC/A40
# 55           imbalanced_classification             SDSC/A40
# 72           imbalanced_classification             OSG/A100
# 69           imbalanced_classification             OSG/A100
# 59           imbalanced_classification             SDSC/A40
# 58           imbalanced_classification             SDSC/A40
# 116   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 98    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 85    text_classification_from_scratch             SDSC/A40
# 84    text_classification_from_scratch             SDSC/A40
# 82    text_classification_from_scratch             SDSC/A40
# 104   text_classification_from_scratch             OSG/A100
# 124   text_classification_from_scratch          OSG/iE52650
# 114   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 110   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 96    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 92    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 123   text_classification_from_scratch          OSG/iE52650
# 119   text_classification_from_scratch          OSG/iE52650
# 115   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 97    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 89    text_classification_from_scratch             SDSC/A40
# 88    text_classification_from_scratch             SDSC/A40
# 111   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 109   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 112   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 93    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 91    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 94    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 117   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 99    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 120   text_classification_from_scratch          OSG/iE52650
# 118   text_classification_from_scratch          OSG/iE52650
# 121   text_classification_from_scratch          OSG/iE52650
# 108   text_classification_from_scratch             OSG/A100
# 107   text_classification_from_scratch             OSG/A100
# 102   text_classification_from_scratch             OSG/A100
# 100   text_classification_from_scratch             OSG/A100
# 103   text_classification_from_scratch             OSG/A100
# 113   text_classification_from_scratch    OSG/AMD_EPYC_7452
# 95    text_classification_from_scratch    OSG/AMD_EPYC_7662
# 127   text_classification_from_scratch             OSG/A100
#
#                         software_environment  fixed-seed  random 2628917891
# 20    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True     0.8176
# 18    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True     0.8176
# 14    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False     0.8296
# 12    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False     0.8296
# 19                  tensorflow_22.06-tf2-py3        True    True    0.85404
# 21   tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True   False    0.85404
# 0    tensorflow_2.10.0-gpu-cuda11.3-cudnn8.2        True    True    0.85404
# 25    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False    0.85584
# 23    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False    0.85584
# 8     tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True    True    0.85584
# 6     tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True    True    0.85584
# 4                   tensorflow_22.10-tf2-py3        True    True    0.85752
# 1                   tensorflow_22.11-tf2-py3        True    True    0.85752
# 5                   tensorflow_22.12-tf2-py3        True    True    0.85752
# 35                  tensorflow_22.10-tf2-py3        True    True    0.85904
# 33                  tensorflow_22.11-tf2-py3        True    True    0.85904
# 42                  tensorflow_22.10-tf2-py3        True    True    0.85904
# 40                  tensorflow_22.11-tf2-py3        True    True    0.85904
# 31    tensorflow_2.8.3-gpu-cuda11.3-cudnn8.2        True   False    0.86552
# 29    tensorflow_2.9.1-gpu-cuda11.3-cudnn8.2        True   False    0.86552
# 37                  tensorflow_22.06-tf2-py3        True    True     0.8672
# 34                  tensorflow_22.09-tf2-py3        True    True     0.8672
# 44                  tensorflow_22.06-tf2-py3        True    True     0.8672
# 41                  tensorflow_22.09-tf2-py3        True    True     0.8672
# 50   tensorflow_2.11.0-gpu-cuda11.8-cudnn8.6       False    True       <NA>
# 51                  tensorflow_22.10-tf2-py3       False    True       <NA>
# 129                 tensorflow_22.10-tf2-py3        True    True   0.790474
# 128                 tensorflow_22.11-tf2-py3        True    True   0.790474
# 130                 tensorflow_22.12-tf2-py3        True    True   0.790474
# 65                  tensorflow_22.06-tf2-py3        True   False   0.978792
# 62                  tensorflow_22.09-tf2-py3        True   False   0.978792
# 70                  tensorflow_22.10-tf2-py3        True   False   0.984972
# 68                  tensorflow_22.11-tf2-py3        True   False   0.984972
# 63                  tensorflow_22.10-tf2-py3        True   False   0.986886
# 61                  tensorflow_22.11-tf2-py3        True   False   0.986886
# 57                  tensorflow_22.06-tf2-py3        True    True   0.990836
# 53                  tensorflow_22.09-tf2-py3        True    True   0.990836
# 74                      tensorflow_2.8.0-gpu        True   False   0.991152
# 73                      tensorflow_2.9.1-gpu        True   False   0.991152
# 79                  tensorflow_22.06-tf2-py3        True   False   0.992047
# 76                  tensorflow_22.09-tf2-py3        True   False   0.992047
# 77                  tensorflow_22.10-tf2-py3        True   False   0.992311
# 75                  tensorflow_22.11-tf2-py3        True   False   0.992311
# 54                  tensorflow_22.10-tf2-py3        True    True   0.992943
# 52                  tensorflow_22.11-tf2-py3        True    True   0.992943
# 55                  tensorflow_22.12-tf2-py3        True    True   0.992943
# 72                  tensorflow_22.06-tf2-py3        True   False    0.99519
# 69                  tensorflow_22.09-tf2-py3        True   False    0.99519
# 59                      tensorflow_2.8.0-gpu        True    True   0.996155
# 58                      tensorflow_2.9.1-gpu        True    True   0.996155
# 116                     tensorflow_2.8.0-gpu        True    True      0.853
# 98                      tensorflow_2.8.0-gpu        True    True      0.853
# 85                      tensorflow_22.10-tf2        True    True     0.8614
# 84                      tensorflow_22.11-tf2        True    True     0.8614
# 82                      tensorflow_22.12-tf2        True    True     0.8614
# 104                        tensorflow_2.10.1        True   False      0.862
# 124                     tensorflow_2.9.1-gpu        True    True      0.862
# 114                 tensorflow_22.06-tf2-py3        True    True     0.8622
# 110                 tensorflow_22.09-tf2-py3        True    True     0.8622
# 96                  tensorflow_22.06-tf2-py3        True    True     0.8622
# 92                  tensorflow_22.09-tf2-py3        True    True     0.8622
# 123                 tensorflow_22.06-tf2-py3        True    True     0.8664
# 119                 tensorflow_22.09-tf2-py3        True    True     0.8664
# 115                     tensorflow_2.9.1-gpu        True    True     0.8666
# 97                      tensorflow_2.9.1-gpu        True    True     0.8666
# 89                      tensorflow_2.8.0-gpu        True    True     0.8672
# 88                      tensorflow_2.9.1-gpu        True    True     0.8672
# 111                 tensorflow_22.10-tf2-py3        True    True     0.8684
# 109                 tensorflow_22.11-tf2-py3        True    True     0.8684
# 112                 tensorflow_22.12-tf2-py3        True    True     0.8684
# 93                  tensorflow_22.10-tf2-py3        True    True     0.8684
# 91                  tensorflow_22.11-tf2-py3        True    True     0.8684
# 94                  tensorflow_22.12-tf2-py3        True    True     0.8684
# 117                    tensorflow_2.10.1-gpu        True    True       0.87
# 99                     tensorflow_2.10.1-gpu        True    True       0.87
# 120                 tensorflow_22.10-tf2-py3        True    True     0.8708
# 118                 tensorflow_22.11-tf2-py3        True    True     0.8708
# 121                 tensorflow_22.12-tf2-py3        True    True     0.8708
# 108                     tensorflow_2.8.0-gpu        True    True      0.872
# 107                     tensorflow_2.9.1-gpu        True    True      0.872
# 102                 tensorflow_22.10-tf2-py3        True    True     0.8738
# 100                 tensorflow_22.11-tf2-py3        True    True     0.8738
# 103                 tensorflow_22.12-tf2-py3        True    True     0.8738
# 113                    tensorflow_2.11.0-gpu        True   False     0.8746
# 95                     tensorflow_2.11.0-gpu        True   False     0.8746
# 127                    tensorflow_2.10.1-gpu       False    True       <NA>
